# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("TESLA.csv")

# %%
df.head(100)
# Out:
#     Unnamed: 0        Date  Open  High   Low     Close  Adj Close     Volume
# 0            0     6/29/10  1.27  1.67  1.17  1.592667   1.592667  281494500
# 1            1     6/30/10  1.72  2.03  1.55  1.588667   1.588667  257806500
# 2            2  07-01-2010  1.67  1.73  1.35  1.464000   1.464000  123282000
# 3            3  07-02-2010  1.53  1.54  1.25  1.280000   1.280000   77097000
# 4            4  07-06-2010  1.33  1.33  1.06  1.074000   1.074000  103003500
# ..         ...         ...   ...   ...   ...       ...        ...        ...
# 95          95  11-11-2010  1.91  1.94  1.82  1.869333   1.869333   29179500
# 96          96  11-12-2010  1.88  2.03  1.87  1.989333   1.989333   40936500
# 97          97    11/15/10  2.01  2.20  2.01  2.053333   2.053333   39343500
# 98          98    11/16/10  2.07  2.09  1.89  1.978000   1.978000   20214000
# 99          99    11/17/10  2.01  2.05  1.91  1.966000   1.966000   11250000
#
# [100 rows x 8 columns]

# %%
df['Open']=pd.to_numeric(df['Open'])

# %%
df['High']=pd.to_numeric(df['High'])

# %%
df['Low']=pd.to_numeric(df['Low'])

# %%
df['Close']=pd.to_numeric(df['Close'])

# %%
df['Adj Close']=pd.to_numeric(df['Adj Close'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3637 entries, 0 to 3636
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3637 non-null   int64
#  1   Date        3637 non-null   object
#  2   Open        3637 non-null   float64
#  3   High        3637 non-null   float64
#  4   Low         3637 non-null   float64
#  5   Close       3637 non-null   float64
#  6   Adj Close   3637 non-null   float64
#  7   Volume      3637 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 227.4+ KB

# %%
print("total null value in the dataset")
ms=df.isnull().sum()
print(ms)
# Out:
# total null value in the dataset
# Unnamed: 0    0
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Adj Close     0
# Volume        0
# dtype: int64

# %%
print("mean value of Open")
print(df['Open'].mean())
# Out:
# mean value of Open
# 80.08056187118751

# %%
print("mean value of High")
print(df['High'].mean())
# Out:
# mean value of High
# 81.83271665822409

# %%
print("mean value of Low")
print(df['Low'].mean())
# Out:
# mean value of Low
# 78.21925152206187

# %%
print("mean value of Close")
print(df['Close'].mean())
# Out:
# mean value of Close
# 80.06795196634037

# %%
print("mean value of Adj Close")
print(df['Adj Close'].mean())
# Out:
# mean value of Adj Close
# 80.06795196634037

# %%
print("median value of Open")
print(df['Open'].median())
# Out:
# median value of Open
# 17.83333206

# %%
print("median value of High")
print(df['High'].median())
# Out:
# median value of High
# 18.07999992

# %%
print("median value of Low")
print(df['Low'].median())
# Out:
# median value of Low
# 17.56399918

# %%
print("median value of Close")
print(df['Close'].median())
# Out:
# median value of Close
# 17.84666634

# %%
print("median value of Adj Close")
print(df['Adj Close'].median())
# Out:
# median value of Adj Close
# 17.84666634

# %%
print("mode value of Open")
print(df['Open'].mode())
# Out:
# mode value of Open
# 0    1.8
# 1    1.9
# Name: Open, dtype: float64

# %%
print("mode value of High")
print(df['High'].mode())
# Out:
# mode value of High
# 0    1.87
# Name: High, dtype: float64

# %%
print("mode value of Low")
print(df['Low'].mode())
# Out:
# mode value of Low
# 0    1.82
# 1    1.87
# Name: Low, dtype: float64

# %%
print("mode value of Close")
print(df['Close'].mode())
# Out:
# mode value of Close
# 0    1.828
# Name: Close, dtype: float64

# %%
print("mode value of Adj Close")
print(df['Adj Close'].mode())
# Out:
# mode value of Adj Close
# 0    1.828
# Name: Adj Close, dtype: float64

# %%
sns.distplot(df['Open'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6896\858187559.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Open'])
# <Axes: xlabel='Open', ylabel='Density'>

# %%
sns.distplot(df['High'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6896\2504026347.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['High'])
# <Axes: xlabel='High', ylabel='Density'>

# %%
sns.distplot(df['Low'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6896\3839789356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Low'])
# <Axes: xlabel='Low', ylabel='Density'>

# %%
sns.distplot(df['Close'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6896\3615683537.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Close'])
# <Axes: xlabel='Close', ylabel='Density'>

# %%
sns.distplot(df['Adj Close'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_6896\2174584222.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Adj Close'])
# <Axes: xlabel='Adj Close', ylabel='Density'>

# %%
sns.scatterplot(df['Open'])
# Out:
# <Axes: ylabel='Open'>

# %%
sns.scatterplot(df['High'])
# Out:
# <Axes: ylabel='High'>

# %%
sns.scatterplot(df['Low'])
# Out:
# <Axes: ylabel='Low'>

# %%
sns.scatterplot(df['Close'])
# Out:
# <Axes: ylabel='Close'>

# %%
sns.scatterplot(df['Adj Close'])
# Out:
# <Axes: ylabel='Adj Close'>

# %%
plt.bar(df['Open'],df['High'],color='green')
plt.xlabel('Open')
plt.ylabel('High')
# Out:
# Text(0, 0.5, 'High')

# %%
plt.bar(df['High'],df['Low'],color='orange')
plt.xlabel('High')
plt.ylabel('Low')
# Out:
# Text(0, 0.5, 'Low')

# %%
plt.bar(df['Low'],df['Close'],color='red')
plt.xlabel('Low')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.bar(df['Close'],df['Adj Close'],color='blue')
plt.xlabel('Close')
plt.ylabel('Adj Close')
# Out:
# Text(0, 0.5, 'Adj Close')

# %%
df.describe()
# Out:
#         Unnamed: 0         Open         High          Low        Close  \
# count  3637.000000  3637.000000  3637.000000  3637.000000  3637.000000
# mean   1818.000000    80.080562    81.832717    78.219252    80.067952
# std    1050.055792   105.466140   107.807165   102.931226   105.409448
# min       0.000000     1.080000     1.110000     1.000000     1.053333
# 25%     909.000000    12.046667    12.320000    11.746667    12.065333
# 50%    1818.000000    17.833332    18.080000    17.563999    17.846666
# 75%    2727.000000   176.070007   179.770004   173.169998   176.880005
# max    3636.000000   411.470001   414.496674   405.666656   409.970001
#
#          Adj Close        Volume
# count  3637.000000  3.637000e+03
# mean     80.067952  9.667330e+07
# std     105.409448  7.787314e+07
# min       1.053333  1.777500e+06
# 25%      12.065333  4.868250e+07
# 50%      17.846666  8.198100e+07
# 75%     176.880005  1.223940e+08
# max     409.970001  9.140820e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3637 entries, 0 to 3636
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3637 non-null   int64
#  1   Date        3637 non-null   object
#  2   Open        3637 non-null   float64
#  3   High        3637 non-null   float64
#  4   Low         3637 non-null   float64
#  5   Close       3637 non-null   float64
#  6   Adj Close   3637 non-null   float64
#  7   Volume      3637 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 227.4+ KB

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,3,1)
plt.boxplot(df['Open'])
plt.ylim(0,100)
plt.title("Open")
plt.subplot(3,3,2)
plt.boxplot(df['High'])
plt.ylim(0,100)
plt.title("High")
plt.subplot(3,3,3)
plt.boxplot(df['Low'])
plt.ylim(0,100)
plt.title("Low")
plt.subplot(3,3,4)
plt.boxplot(df['Close'])
plt.ylim(0,100)
plt.title("Close")
plt.subplot(3,3,5)
plt.boxplot(df['Adj Close'])
plt.ylim(0,100)
plt.title("Adj Close")
# Out:
# Text(0.5, 1.0, 'Adj Close')

# %%
#standardize of Data & eliminating string  type Cloumn 
df1=df.iloc[:,2:]
name=df1.columns
nm=df1[name]
scaler=StandardScaler()
scaler.fit(nm)
# Out:
# StandardScaler()

# %%
scaledata=scaler.transform(nm)
scaledata.shape
# Out:
# (3637, 6)

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3637.000000  3637.000000  3637.000000  3637.000000  3637.000000
# mean     80.080562    81.832717    78.219252    80.067952    80.067952
# std     105.466140   107.807165   102.931226   105.409448   105.409448
# min       1.080000     1.110000     1.000000     1.053333     1.053333
# 25%      12.046667    12.320000    11.746667    12.065333    12.065333
# 50%      17.833332    18.080000    17.563999    17.846666    17.846666
# 75%     176.070007   179.770004   173.169998   176.880005   176.880005
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.637000e+03
# mean   9.667330e+07
# std    7.787314e+07
# min    1.777500e+06
# 25%    4.868250e+07
# 50%    8.198100e+07
# 75%    1.223940e+08
# max    9.140820e+08

# %%
pca=PCA()
pca.fit(scaledata)
plt.figure(figsize=(5,5))
f=range(pca.n_components_)
#print(f)
print(pca.explained_variance_)
plt.bar(f,pca.explained_variance_)
plt.xlabel('PCA Features')
plt.ylabel('Variance')
plt.title('Principal Component Analysis')
# Out:
# [5.01129641e+00 9.88818841e-01 1.11184916e-03 3.33486748e-04
#  8.95778355e-05 0.00000000e+00]
# Text(0.5, 1.0, 'Principal Component Analysis')

# %%
pca=PCA(n_components=1)
pca.fit(scaledata)
# Out:
# PCA(n_components=1)

# %%
x_pca=pca.transform(scaledata)

# %%
x_pca.shape
x_pca
pcaDf = pd.DataFrame(data = x_pca, columns = ['pca1'])
pcaDf
# Out:
#           pca1
# 0    -1.538398
# 1    -1.549639
# 2    -1.645324
# 3    -1.680387
# 4    -1.666898
# ...        ...
# 3632  5.729927
# 3633  5.796782
# 3634  6.063930
# 3635  6.412768
# 3636  6.608034
#
# [3637 rows x 1 columns]

# %%
#copy value of Dataframe indf_outlier
df_outlier=df

# %%
df_outlier = pcaDf.copy()

# %%
#convert to datetime datatype
df['Date'] = pd.to_datetime(df['Date'])
anomaly['Date'] = pd.to_datetime(anomaly['Date'])
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3106791471.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
#Quantile and IQR Calculation
q1_pca1, q3_pca1 = pcaDf['pca1'].quantile([0.25, 0.75])
iqr_pca1 = q3_pca1 - q1_pca1
#Outlier Boundaries :Calculate upper and lower bounds for outlier for pca1
lower_pca1 = q1_pca1 - (1.5 * iqr_pca1)
x_lower_pca1 = q1_pca1 - (3 * iqr_pca1)#extreme lower bound
upper_pca1 = q3_pca1 + (1.5 * iqr_pca1)
x_upper_pca1 = q3_pca1 + (3 * iqr_pca1)#extreme upper bound
#Anomaly Detection: Filter out the outliers from the pca1
df_outlier['anomaly_pca1'] = ((pcaDf['pca1'] > upper_pca1) | (pcaDf['pca1'] < lower_pca1)).astype('int')
#Extracting Anomalies
anomaly = df[df_outlier['anomaly_pca1'] == 1]
#Plotting Anomalies:plotting outlier/anomaly with original data
plt.figure(figsize=(18,6))
#for date plotiing
plt.plot_date(df['Date'], df['Open'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'], anomaly['Open'], linestyle='none', marker='.', color='red', label='Anomaly')
plt.xlabel('Date')
plt.ylabel('Open Reading')
plt.title('Open Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3749166484.py:16: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['Open'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3749166484.py:17: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'], anomaly['Open'], linestyle='none', marker='.', color='red', label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3749166484.py:17: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'], anomaly['Open'], linestyle='none', marker='.', color='red', label='Anomaly')

# %%
#Taking extreme upper and lower bound. Therefore taking extreme outliers  for column Open
df_outlier['anomaly_pca1'] = ((pcaDf['pca1']>x_upper_pca1) | (pcaDf['pca1']<x_lower_pca1)).astype('int')
anomaly = df[df_outlier['anomaly_pca1'] == 1]
plt.figure(figsize=(18,6))
plt.plot_date(df['Date'], df['Open'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'],anomaly['Open'], linestyle='none', marker='.', color='red',label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Open Reading')
plt.title('Open Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2697002645.py:5: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['Open'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2697002645.py:6: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'],anomaly['Open'], linestyle='none', marker='.', color='red',label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2697002645.py:6: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'],anomaly['Open'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
#Taking extreme upper and lower bound. Therefore taking extreme outliers  for column High
plt.figure(figsize=(18,6))
plt.plot_date(df['Date'], df['High'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'],anomaly['High'], linestyle='none', marker='.', color='red',label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('High Reading')
plt.title('High Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3224653624.py:3: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['High'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3224653624.py:4: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'],anomaly['High'], linestyle='none', marker='.', color='red',label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\3224653624.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'],anomaly['High'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
#Taking extreme upper and lower bound. Therefore taking extreme outliers  for column Low
plt.figure(figsize=(18,6))
plt.plot_date(df['Date'], df['Low'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'],anomaly['Low'], linestyle='none', marker='.', color='red',label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Low Reading')
plt.title('Low Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2900880820.py:3: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['Low'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2900880820.py:4: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'],anomaly['Low'], linestyle='none', marker='.', color='red',label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\2900880820.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'],anomaly['Low'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
#Taking extreme upper and lower bound. Therefore taking extreme outliers  for column Close
plt.figure(figsize=(18,6))
plt.plot_date(df['Date'], df['Close'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'],anomaly['Close'], linestyle='none', marker='.', color='red',label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Close Reading')
plt.title('Close Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\678639814.py:3: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['Close'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\678639814.py:4: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'],anomaly['Close'], linestyle='none', marker='.', color='red',label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\678639814.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'],anomaly['Close'], linestyle='none', marker='.', color='red',label='Anomaly')

# %%
#Taking extreme upper and lower bound. Therefore taking extreme outliers  for column Adj Close
plt.figure(figsize=(18,6))
plt.plot_date(df['Date'], df['Adj Close'], color='blue', label='Normal')
plt.plot_date(anomaly['Date'],anomaly['Adj Close'], linestyle='none', marker='.', color='red',label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel('Adj Close Reading')
plt.title('Adj Close Anomalies')
plt.legend(loc=4)
plt.show();
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\148451364.py:3: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(df['Date'], df['Adj Close'], color='blue', label='Normal')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\148451364.py:4: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(anomaly['Date'],anomaly['Adj Close'], linestyle='none', marker='.', color='red',label='Anomaly')
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_3552\148451364.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(anomaly['Date'],anomaly['Adj Close'], linestyle='none', marker='.', color='red',label='Anomaly')
